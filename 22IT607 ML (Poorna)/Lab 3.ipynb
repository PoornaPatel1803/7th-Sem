# %% [markdown]
# # Lab 3

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('./Churn.csv',usecols=["gender","tenure"])
print("df.tail()")
df = pd.read_csv('./Churn.csv')
print(df.head())
# Out:
# df.tail()
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')
# (7043, 21)

# %%
print("MontlyCharge, TotalCharges columns dropped")
df.drop(["MonthlyCharges","TotalCharges"],axis='columns')
df.head()
# Out:
# MontlyCharge, TotalCharges columns dropped
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df = pd.read_csv('./Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.sample(18)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6616  9600-NAXZN    Male              0      No         No      43
# 3540  1053-MXTTK  Female              0     Yes        Yes      72
# 2629  5028-GZLDO    Male              0      No         No       2
# 6788  1760-CAZHT    Male              0      No        Yes      25
# 5143  5204-HMGYF  Female              0     Yes        Yes      49
# 424   8111-BKVDS  Female              0      No         No      10
# 4004  5803-NQJZO    Male              0     Yes         No      72
# 1264  6244-BESBM    Male              0     Yes        Yes      69
# 3633  3878-AVSOQ  Female              1      No         No       1
# 2201  7951-VRDVK  Female              0      No         No      36
# 4678  3006-XIMLN  Female              0      No        Yes       2
# 1569  0799-DDIHE  Female              0     Yes        Yes      15
# 467   5968-XQIVE    Male              0     Yes        Yes      72
# ...

# %%
print(df.isna().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print(df.isna().sum().sum())
# Out:
# 0

# %%
import numpy as np
missing_value = np.random.randint(7043,size=20)
print(missing_value)
# Out:
# [3315 3157 1899  385 2623 4828 1535 2261 4006 2355 3255 5919 5647 6637
#   883 5403 6620 6144 2364 3594]

# %%
row1 = df.iloc[missing_value] = np.nan
print(df.isna().sum())
# Out:
# customerID          20
# gender              20
# SeniorCitizen       20
# Partner             20
# Dependents          20
# tenure              20
# PhoneService        20
# MultipleLines       20
# InternetService     20
# OnlineSecurity      20
# OnlineBackup        20
# DeviceProtection    20
# TechSupport         20
# StreamingTV         20
# StreamingMovies     20
# Contract            20
# PaperlessBilling    20
# PaymentMethod       20
# MonthlyCharges      20
# TotalCharges        20
# Churn               20
# dtype: int64

# %%
df["gender"].value_counts().sum()
# Out:
# 7023

# %%
avg = int(df['tenure'].mean())
print(avg)
# Out:
# 32

# %%
print(df['gender'].fillna(value=avg,inplace=True))
# Out:
# None

# %%
print(df.isna().sum().sum())
print(df)
# Out:
# 400
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.dropna(axis=0,inplace=True)
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print(df.loc[(df['gender'] == 'Male') & (df['MonthlyCharges'] < 20)])
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 11    7469-LKBCI   Male            0.0      No         No    16.0
# 21    1680-VDCWW   Male            0.0     Yes         No    12.0
# 109   2848-YXSMW   Male            0.0     Yes        Yes    72.0
# 128   3930-ZGWVE   Male            0.0      No         No     1.0
# 138   6217-KDYWC   Male            0.0      No        Yes    57.0
# ...          ...    ...            ...     ...        ...     ...
# 6944  9039-ZVJDC   Male            0.0      No         No     3.0
# 6951  9588-YRFHY   Male            0.0      No         No    49.0
# 6954  9364-YKUVW   Male            0.0      No         No    15.0
# 7005  9347-AERRL   Male            0.0     Yes         No    23.0
# 7020  9837-FWLCH   Male            0.0     Yes        Yes    12.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 11            Yes            No              No  No internet service  ...
# ...

# %%
gk = df.groupby('gender')

# %%
gk.first()
# Out:
#         customerID  SeniorCitizen Partner Dependents  tenure PhoneService  \
# gender
# Female  7590-VHVEG            0.0     Yes         No     1.0           No
# Male    5575-GNVDE            0.0      No         No    34.0          Yes
#
#            MultipleLines InternetService OnlineSecurity OnlineBackup  \
# gender
# Female  No phone service             DSL             No          Yes
# Male                  No             DSL            Yes           No
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# gender
# Female               No          No          No              No
# Male                Yes          No          No              No
#
#               Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# gender
# Female  Month-to-month              Yes  Electronic check           29.85
# Male          One year               No      Mailed check           56.95
#
#        TotalCharges Churn
# gender
# Female        29.85    No
# ...
